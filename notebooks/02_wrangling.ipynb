# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: numpy>=1.24.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (2.4.6)
# Requirement already satisfied: scikit-learn>=1.2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: tensorflow>=2.12.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (2.21.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 10)) (3.10.9)
# Requirement already satisfied: seaborn>=0.12.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: plotnine>=0.12.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 12)) (0.15.4)
# Requirement already satisfied: kagglehub>=0.3.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 15)) (1.0.1)
# Requirement already satisfied: ipykernel in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 18)) (7.2.0)
# Requirement already satisfied: jupyter in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: quarto in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 20)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: packaging in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.34.2)
# Requirement already satisfied: setuptools in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2026.5.20)
# Requirement already satisfied: contourpy>=1.0.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: mizani~=0.14.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.4)
# Requirement already satisfied: statsmodels>=0.14.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 15)) (0.1.23)
# Requirement already satisfied: pyyaml in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 15)) (6.0.3)
# Requirement already satisfied: tqdm in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 15)) (4.67.3)
# Requirement already satisfied: comm>=0.1.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (5.15.0)
# Requirement already satisfied: notebook in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 19)) (7.5.6)
# Requirement already satisfied: jupyter-console in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 19)) (6.6.3)
# Requirement already satisfied: nbconvert in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 19)) (7.17.1)
# Requirement already satisfied: ipywidgets in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 19)) (8.1.8)
# Requirement already satisfied: jupyterlab in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 19)) (4.5.7)
# Requirement already satisfied: nbformat in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from quarto->-r ../requirements.txt (line 20)) (5.10.4)
# Requirement already satisfied: nbclient in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from quarto->-r ../requirements.txt (line 20)) (0.10.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.47.0)
# Requirement already satisfied: decorator>=5.1.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.6.3)
# Requirement already satisfied: wcwidth in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r ../requirements.txt (line 18)) (4.9.6)
# Requirement already satisfied: rich in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (15.0.0)
# Requirement already satisfied: namex in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: optree in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (3.0.1)
# Requirement already satisfied: pure-eval in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from statsmodels>=0.14.6->plotnine>=0.12.0->-r ../requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 19)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 19)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.2.4)
# Requirement already satisfied: anyio in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.1.1)
# Requirement already satisfied: fqdn in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: isoduration in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: uri-template in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 19)) (6.3.0)
# Requirement already satisfied: defusedxml in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: webencodings in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from nbformat->quarto->-r ../requirements.txt (line 20)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.0.0)
# Requirement already satisfied: pycparser in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 19)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: tzdata in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2026.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /media/hamza/shared3/Projects/aptispace-datascience-projet/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 🧹 Étape 2 : Préparation & Nettoyage de Données (Data Wrangling) (Squelette Étudiant)
#
# Cette étape correspond au deuxième chapitre du projet. L'objectif est d'effectuer un audit de qualité de vos données brutes, puis de mettre en œuvre un nettoyage rigoureux à l'aide de votre package personnalisé `src.data_clean`.

# %% [markdown]
# ### 1. Importations et configuration du chemin src

# %%
import os
import sys
import pandas as pd

# Ajout du dossier racine au chemin pour pouvoir importer le module src
sys.path.append(os.path.abspath(os.path.join('..')))
import src.data_clean as dc

# %% [markdown]
# ### 2. Chargement du dataset brut et Audit Initial
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Chargez les données brutes et inspectez la qualité du dataset (taux de valeurs manquantes, présence de doublons, types erronés).

# %%
print("Chargement des données brutes...")
df_raw_players = pd.read_csv("../data/raw/players.csv")
df_raw_appearances = pd.read_csv("../data/raw/appearances.csv")
# Out:
# Chargement des données brutes...

# %% [markdown]
# ### 3. Nettoyage et Imputation

# %%
print("Application des filtres et imputations...")
# 1. Traitement des dates
df_cleaned_players = dc.clean_dates(df_raw_players, ['date_of_birth', 'last_season'])

# 2. Calcul de l'âge (Variable cruciale dérivée de la date de naissance)
current_year = pd.Timestamp.now().year
df_cleaned_players['age'] = current_year - df_cleaned_players['date_of_birth'].dt.year
# Remplacement des âges aberrants si présents par la médiane
df_cleaned_players['age'] = df_cleaned_players['age'].fillna(df_cleaned_players['age'].median())

# 3. Imputation des valeurs manquantes (Taille, Pied fort, Valeur marchande)
df_cleaned_players = dc.impute_missing_data(df_cleaned_players)
# Out:
# Application des filtres et imputations...

# %% [markdown]
# ### 4. Agrégation des performances de matchs

# %%
print("Agrégation des statistiques de matchs par joueur...")
df_perf_aggregated = dc.aggregate_performances(df_raw_appearances)
# Out:
# Agrégation des statistiques de matchs par joueur...

# %% [markdown]
# ### 5. Fusion finale et Sauvegarde

# %%
print("Fusion des sources et création du dataset d'apprentissage...")
df_final = dc.build_final_dataset(df_cleaned_players, df_perf_aggregated)

# Création du dossier processed s'il n'existe pas
os.makedirs("../data/processed/", exist_ok=True)

# Sauvegarde au format CSV pour les étapes d'EDA et de Modélisation
output_path = "../data/processed/football_ml_dataset.csv"
df_final.to_csv(output_path, index=False)

print(f"\n[SUCCÈS] Data Wrangling terminé !")
print(f"Le dataset propre contient {df_final.shape[0]} joueurs et {df_final.shape[1]} caractéristiques.")
print(f"Fichier sauvegardé dans : {output_path}")
# Out:
# Fusion des sources et création du dataset d'apprentissage...
#
# [SUCCÈS] Data Wrangling terminé !
# Le dataset propre contient 28712 joueurs et 31 caractéristiques.
# Fichier sauvegardé dans : ../data/processed/football_ml_dataset.csv

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# Chargement du fichier traité
df_processed = pd.read_csv("../data/processed/football_ml_dataset.csv")

# Affichage des 5 premières lignes sous forme de joli tableau HTML interactif
df_processed.head(10)
# Out:
#    player_id first_name     last_name                 name  \
# 0         10   Miroslav         Klose       Miroslav Klose
# 1         26      Roman  Weidenfeller   Roman Weidenfeller
# 2         65    Dimitar      Berbatov     Dimitar Berbatov
# 3         77        NaN         Lúcio                Lúcio
# 4         80        Tom        Starke           Tom Starke
# 5        109        NaN          Dedê                 Dedê
# 6        123  Christoph     Metzelder  Christoph Metzelder
# 7        132      Tomas       Rosicky        Tomas Rosicky
# 8        215      Roque    Santa Cruz     Roque Santa Cruz
# 9        258     Gerald       Asamoah       Gerald Asamoah
#
#                      last_season  current_club_id    country_of_birth  \
# 0  1970-01-01 00:00:00.000002015              398              Poland
# 1  1970-01-01 00:00:00.000002017               16             Germany
# 2  1970-01-01 00:00:00.000002015             1091            Bulgaria
# 3  1970-01-01 00:00:00.000002012              506              Brazil
# 4  1970-01-01 00:00:00.000002017               27  East Germany (GDR)
# 5  1970-01-01 00:00:00.000002013              825              Brazil
# 6  1970-01-01 00:00:00.000002012               33             Germany
# 7  1970-01-01 00:00:00.000002015               11                CSSR
# 8  1970-01-01 00:00:00.000002015             1084            Paraguay
# 9  1970-01-01 00:00:00.000002013               33               Ghana
#
#     city_of_birth country_of_citizenship date_of_birth        sub_position  \
# 0           Opole                Germany    1978-06-09      Centre-Forward
# 1            Diez                Germany    1980-08-06          Goalkeeper
# 2     Blagoevgrad               Bulgaria    1981-01-30      Centre-Forward
# 3        Brasília                 Brazil    1978-05-08         Centre-Back
# 4         Freital                Germany    1981-03-18          Goalkeeper
# 5  Belo Horizonte                 Brazil    1978-04-18           Left-Back
# 6         Haltern                Germany    1980-11-05         Centre-Back
# 7           Praha         Czech Republic    1980-10-04  Attacking Midfield
# 8        Asunción               Paraguay    1981-08-16      Centre-Forward
# 9         Mampong                Germany    1978-10-03      Centre-Forward
#
#      position   foot  height_in_cm contract_expiration_date  \
# 0      Attack  right     184.00000                      NaN
# 1  Goalkeeper   left     190.00000                      NaN
# 2      Attack  right     182.02293                      NaN
# 3    Defender  right     182.02293                      NaN
# 4  Goalkeeper  right     194.00000                      NaN
# 5    Defender  right     182.02293                      NaN
# 6    Defender  right     182.02293                      NaN
# 7    Midfield   both     179.00000                      NaN
# 8      Attack  right     193.00000      2023-12-31 00:00:00
# 9      Attack  right     180.00000                      NaN
#
#              agent_name  international_caps  international_goals  \
# 0  ASBW Sport Marketing                 NaN                  NaN
# 1      Neubauer 13 GmbH                 NaN                  NaN
# 2       CSKA-AS-23 Ltd.                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   IFM                 NaN                  NaN
# 5      Football Concept                 NaN                  NaN
# 6                   NaN                 NaN                  NaN
# 7                   NaN                 NaN                  NaN
# 8                   NaN                 NaN                  NaN
# 9                   NaN                 NaN                  NaN
#
#    current_national_team_id current_club_domestic_competition_id  \
# 0                       NaN                                  IT1
# 1                       NaN                                   L1
# 2                       NaN                                  GR1
# 3                       NaN                                  IT1
# 4                       NaN                                   L1
# 5                       NaN                                  TR1
# 6                       NaN                                   L1
# 7                       NaN                                  GB1
# 8                       NaN                                  ES1
# 9                       NaN                                   L1
#
#                                    current_club_name  market_value_in_eur  \
# 0                      Società Sportiva Lazio S.p.A.            1000000.0
# 1                                  Borussia Dortmund             750000.0
# 2  Panthessalonikios Athlitikos Omilos Konstantin...            1000000.0
# 3                             Juventus Football Club             200000.0
# 4                                  FC Bayern München             100000.0
# 5                                      Eskisehirspor             400000.0
# 6                                      FC Schalke 04            1500000.0
# 7                              Arsenal Football Club             350000.0
# 8                                          Málaga CF             250000.0
# 9                                      FC Schalke 04             100000.0
#
#    highest_market_value_in_eur   age  goals  assists  minutes_played  \
# 0                   30000000.0  48.0     48       25            8808
# 1                    8000000.0  46.0      0        0           13508
# 2                   34500000.0  45.0     38       13            8788
# 3                   24500000.0  48.0      0        0             307
# 4                    3000000.0  45.0      0        0            1080
# 5                    9500000.0  48.0      1        2            3584
# 6                    9500000.0  46.0      0        1             427
# 7                   17500000.0  46.0      9        4            3987
# 8                   12000000.0  45.0     26        8            6038
# 9                    7000000.0  48.0      0        2            1075
#
#    yellow_cards  red_cards  goals_per_90  assists_per_90
# 0            19          0      0.490408        0.255421
# 1             4          2      0.000000        0.000000
# 2            11          1      0.389123        0.133121
# 3             0          0      0.000000        0.000000
# 4             0          0      0.000000        0.000000
# 5             4          0      0.025105        0.050209
# 6             0          0      0.000000        0.210280
# 7            13          0      0.203109        0.090271
# 8             3          0      0.387481        0.119225
# 9             2          0      0.000000        0.167286
